# %%
import numpy as np #NumPy = hızlı sayısal hesaplama motoru

#Pandas = veri analizi için pratik ve güçlü bir tablo yöneticisi (NumPy üzerine kurulu)
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\T008943\\Desktop\\archive\\cleaned_global_water_consumption.csv")
df
# Out:
#        Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0    Argentina  2000                                      481.490000
# 1    Argentina  2001                                      455.063000
# 2    Argentina  2002                                      482.749231
# 3    Argentina  2003                                      452.660000
# 4    Argentina  2004                                      634.566000
# ..         ...   ...                                             ...
# 495        USA  2020                                      418.097000
# 496        USA  2021                                      572.094000
# 497        USA  2022                                      440.978000
# 498        USA  2023                                      566.865000
# 499        USA  2024                                      249.485000
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# ...

# %%
df.head() #pandas kütüphanesindeki bir metottur ve bir DataFrame’in ilk satırlarını görmeni sağlar.
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0  Argentina  2000                                      481.490000
# 1  Argentina  2001                                      455.063000
# 2  Argentina  2002                                      482.749231
# 3  Argentina  2003                                      452.660000
# 4  Argentina  2004                                      634.566000
#
#    Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# 0                             235.431429                   48.550000
# 1                             299.551000                   48.465000
# 2                             340.124615                   50.375385
# 3                             326.756667                   49.086667
# 4                             230.346000                   38.670000
#
#    Industrial Water Use (%)  Household Water Use (%)  \
# 0                 20.844286                30.100000
# ...

# %%
df["Country"].unique() # Country kolonundaki uniq olan ülkeleri döndürür.
# Out:
# array(['Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'France',
#        'Germany', 'India', 'Indonesia', 'Italy', 'Japan', 'Mexico',
#        'Russia', 'Saudi Arabia', 'South Africa', 'South Korea', 'Spain',
#        'Turkey', 'UK', 'USA'], dtype=object)

# %%
df["Country"].value_counts() #Seçilen serideki her benzersiz değerin kaç kez geçtiğini sayar.
# Out:
# Country
# Argentina       25
# Australia       25
# Brazil          25
# Canada          25
# China           25
# France          25
# Germany         25
# India           25
# Indonesia       25
# Italy           25
# Japan           25
# Mexico          25
# Russia          25
# Saudi Arabia    25
# South Africa    25
# South Korea     25
# Spain           25
# Turkey          25
# UK              25
# USA             25
# Name: count, dtype: int64

# %%
df.groupby("Country")[["Industrial Water Use (%)"]].mean().reset_index()
# Out:
#          Country  Industrial Water Use (%)
# 0      Argentina                 27.946761
# 1      Australia                 28.724404
# 2         Brazil                 26.612297
# 3         Canada                 29.465351
# 4          China                 27.854793
# 5         France                 26.136218
# 6        Germany                 28.645995
# 7          India                 27.919001
# 8      Indonesia                 26.853027
# 9          Italy                 28.078849
# 10         Japan                 28.821843
# 11        Mexico                 27.989065
# 12        Russia                 27.703461
# 13  Saudi Arabia                 27.714798
# 14  South Africa                 28.687093
# 15   South Korea                 24.763615
# 16         Spain                 27.785028
# 17        Turkey                 29.102001
# 18            UK                 27.690948
# 19           USA                 27.362197

# %%
df.groupby("Country")[["Industrial Water Use (%)"]].mean().reset_index().sort_values(by="Industrial Water Use (%)",ascending=False)
# Out:
#          Country  Industrial Water Use (%)
# 3         Canada                 29.465351
# 17        Turkey                 29.102001
# 10         Japan                 28.821843
# 1      Australia                 28.724404
# 14  South Africa                 28.687093
# 6        Germany                 28.645995
# 9          Italy                 28.078849
# 11        Mexico                 27.989065
# 0      Argentina                 27.946761
# 7          India                 27.919001
# 4          China                 27.854793
# 16         Spain                 27.785028
# 13  Saudi Arabia                 27.714798
# 12        Russia                 27.703461
# 18            UK                 27.690948
# 19           USA                 27.362197
# 8      Indonesia                 26.853027
# 2         Brazil                 26.612297
# 5         France                 26.136218
# 15   South Korea                 24.763615

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#               Year  Total Water Consumption (Billion Cubic Meters)  \
# count   500.000000                                      500.000000
# mean   2012.000000                                      501.224430
# std       7.218324                                       96.078937
# min    2000.000000                                      129.636667
# 25%    2006.000000                                      441.447385
# 50%    2012.000000                                      502.197154
# 75%    2018.000000                                      563.849594
# max    2024.000000                                      798.418000
#
#        Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# count                             500.000000                  500.000000
# mean                              276.004782                   50.180829
# std                                42.669593                    5.566886
# ...

# %%
turkey_df = df.loc[df["Country"] == "Turkey"]

# %%
turkey_df=df

# %%
df
# Out:
#        Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0    Argentina  2000                                      481.490000
# 1    Argentina  2001                                      455.063000
# 2    Argentina  2002                                      482.749231
# 3    Argentina  2003                                      452.660000
# 4    Argentina  2004                                      634.566000
# ..         ...   ...                                             ...
# 495        USA  2020                                      418.097000
# 496        USA  2021                                      572.094000
# 497        USA  2022                                      440.978000
# 498        USA  2023                                      566.865000
# 499        USA  2024                                      249.485000
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# ...

# %%
df = df.loc[df["Country"] == "Turkey"]

# %%
df
# Out:
#     Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 425  Turkey  2000                                      621.265385
# 426  Turkey  2001                                      372.417000
# 427  Turkey  2002                                      364.634167
# 428  Turkey  2003                                      326.113333
# 429  Turkey  2004                                      580.200714
# 430  Turkey  2005                                      250.215714
# 431  Turkey  2006                                      238.577778
# 432  Turkey  2007                                      507.527619
# 433  Turkey  2008                                      561.042222
# 434  Turkey  2009                                      588.559231
# 435  Turkey  2010                                      559.448333
# 436  Turkey  2011                                      656.747000
# 437  Turkey  2012                                      528.561818
# ...

# %%
group_category_consumption = df.groupby("Year")[["Total Water Consumption (Billion Cubic Meters)"]].mean().reset_index()

plt.figure(figsize=(18,5))
plt.bar(x = "Year", height = "Total Water Consumption (Billion Cubic Meters)", data = group_category_consumption)
plt.xticks(rotation=90);
